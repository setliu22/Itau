# %%
# %cd ~/Itau
# %run notebooks/substitution_labeler.py
# Out:
# /home/setliu22/Itau
# ...

# %%
import ipywidgets as widgets
widgets.IntSlider(description="Test")
# Out:
# IntSlider(value=0, description='Test')
