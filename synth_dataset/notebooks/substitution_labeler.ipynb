# %%
from pathlib import Path

repo_root = Path.cwd()
if not (repo_root / "Synthetic Dataset").exists():
    repo_root = Path.home() / "Itau"
# %cd $repo_root
# %run "synth_dataset/scripts/substitution_labeler.py"
# Out:
# /home/setliu22/Itau
# ...
